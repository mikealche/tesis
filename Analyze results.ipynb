# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Color Correction (Max RGB)

# %%
runs = {}
for i in range(1,9):
    runs[i] = pd.read_csv(f'run_seed_{i}.txt')
    runs[i].plot()

# %%
times_max_rgb_had_higher_acc = [runs[i].max()['Without Color Correction'] < runs[i].max()[' Max_RGB'] for i in runs]

# %%
arl_effectiveness = sum(times_max_rgb_had_higher_acc)/ len(runs)

# %%
print(f'MAX RGB improved the Accuracy in {arl_effectiveness*100}% of the cases')
# Out:
# MAX RGB improved the Accuracy in 62.5% of the cases

# %% [markdown]
# # Resnet with and without ARL

# %%
runs = {}
for i in range(1,9):
    runs[i] = pd.read_csv(f'attn_run_seed_{i}.txt')
    runs[i].plot()

# %%
times_arl_had_higher_acc = [runs[i].max()['Baseline'] < runs[i].max()[' With ARL'] for i in runs]

# %%
arl_effectiveness = sum(times_arl_had_higher_acc)/ len(runs)

# %%
print(f'ARL improved the Accuracy in {arl_effectiveness*100}% of the cases')
# Out:
# ARL improved the Accuracy in 75.0% of the cases

# %% [markdown]
# # EfficientNet-b0 with and without ARL

# %%
runs = {}
for i in range(1,9):
    runs[i] = pd.read_csv(f'EfficientNet_attn_run_seed_{i}.txt')
    runs[i].plot()

# %%
times_eff_arl_had_higher_acc = [runs[i].max()['Baseline'] < runs[i].max()[' EfficientNet With ARL'] for i in runs]

# %%
eff_arl_effectiveness = sum(times_eff_arl_had_higher_acc)/ len(runs)

# %%
print(f'EfficientNet ARL improved the Accuracy in {eff_arl_effectiveness*100}% of the cases')
# Out:
# EfficientNet ARL improved the Accuracy in 50.0% of the cases
