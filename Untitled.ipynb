# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from exp.nb_Tesis import *

# %%
# !wget https://challenge.kitware.com/api/v1/item/584ad09dcad3a51cc66c8e15/download

# %%
# !wget https://challenge.kitware.com/api/v1/item/5849dadccad3a51cc66c8e08/download

# %%
path_train_images = Path('2017/ISIC-2017_Training_Data/')

# %%
path_ground_truth = Path('2017/gt')
# path_test_images = Path('segmented_images/square/ISIC2018_Task3_Test_Input/')

# %%
df = pd.read_csv(path_ground_truth); print(f'{len(df)} images: ')
df['nv'] = ((df['melanoma'] + df['seborrheic_keratosis']) + 1) % 2
dfSingleLabel = pd.DataFrame({'image_id':df['image_id'] })
labelcols = df.columns[1:len(df.columns)]
dfSingleLabel['label'] = df[list(labelcols)].idxmax(axis='columns')
dfSingleLabel.head()
# Out:
# 2000 images:
#        image_id     label
# 0  ISIC_0000000        nv
# 1  ISIC_0000001        nv
# 2  ISIC_0000002  melanoma
# 3  ISIC_0000003        nv
# 4  ISIC_0000004  melanoma

# %%
dfSingleLabel.groupby('label').count()
# Out:
#                       image_id
# label
# melanoma                   374
# nv                        1372
# seborrheic_keratosis       254

# %%
dfSingleLabel.loc[dfSingleLabel['image_id'] == 'ISIC_0013706']
# Out:
#           image_id                 label
# 1574  ISIC_0013706  seborrheic_keratosis

# %%
'asd'.replace('sw','d')
# Out:
# 'asd'

# %%
labels_for_2017_live_challenge = ['melanoma', 'nv', 'seborrheic_keratosis']
def get_label_for_image_name(image_name):
  return list(dfSingleLabel.loc[dfSingleLabel['image_id']==image_name].label)[0]

def get_label_for_image_path(image_path): 
#     print(image_path)
    return get_label_for_image_name(image_path.name[:-4].replace('_superpixels',''))
# def get_label_for_image_path(image_path): print(image_path)

# %%
get_label_for_image_path(Path('2017/ISIC-2017_Training_Data/ISIC_0000010.jpg'))
# Out:
# 'nv'

# %%
n_of_images_to_keep_per_class = 500
path_reduced_ds =  (path_train_images / f'reduced-{n_of_images_to_keep_per_class}')
path_reduced_ds.mkdir(exist_ok=True)
path_reduced_ds
# Out:
# PosixPath('2017/ISIC-2017_Training_Data/reduced-500')

# %%
for label in labels_for_2018_live_challenge:
    for row in dfSingleLabel.loc[dfSingleLabel['label']==label].head(n_of_images_to_keep_per_class).itertuples():
        path_img_orig = path_train_images / (row.image + '.jpg')
        # !cp $path_img_orig $path_reduced_ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-964003232468> in <module>
#       1 for label in labels_for_2018_live_challenge:
# ----> 2     for row in dfSingleLabel.loc[dfSingleLabel['label']==label].head(n_of_images_to_keep_per_class).itertuples():
#       3         path_img_orig = path_train_images / (row.image + '.jpg')
#       4         get_ipython().system('cp $path_img_orig $path_reduced_ds')
#       5
#
# NameError: name 'n_of_images_to_keep_per_class' is not defined

# %%
def random_seed(seed_value, use_cuda):  #gleaned from multiple forum posts
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda: torch.cuda.manual_seed_all(seed_value) # gpu

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.functional")

# %%
random_seed(42,True)
tfms = get_transforms(flip_vert=True, max_rotate=180,max_zoom=.5, max_lighting=.3,p_affine=1)
#Descomentar para correccion de color
# tfms[0].append(correct_color())
# tfms[1].append(correct_color())

data = ImageList.from_folder(path_train_images)\
.split_by_rand_pct()\
.label_from_func(get_label_for_image_path)\
.transform(tfms,size=128)\
.databunch(bs=32)\
.normalize()

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1600 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# nv,nv,seborrheic_keratosis,nv,nv
# Path: 2017/ISIC-2017_Training_Data;
#
# Valid: LabelList (400 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# nv,nv,nv,melanoma,nv
# Path: 2017/ISIC-2017_Training_Data;
#
# Test: None

# %%
data.show_batch(rows=5, figsize=(10,10))

# %%
vc = pd.value_counts(data.train_ds.y.items, sort=False)
vc.index = data.classes; vc
# Out:
# melanoma                 300
# nv                      1105
# seborrheic_keratosis     195
# dtype: int64

# %%
# del learn
# del data

torch.cuda.empty_cache()
gc.collect()
# Out:
# 174

# %%
# !nvidia-smi
# Out:
# Tue Nov 26 19:00:49 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.87.00    Driver Version: 418.87.00    CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:05:00.0 Off |                  N/A |
# |  0%   31C    P2    55W / 250W |    567MiB / 11177MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:09:00.0 Off |                  N/A |
# |  0%   24C    P5    10W / 250W |     10MiB / 11178MiB |      0%      Default |
# ...

# %%
random_seed(7,True)
# x50 = lambda x: xresnet50()
learn = cnn_learner(data,models.resnet101, 
                    metrics=[error_rate,accuracy,auc_roc_score()],
                    callback_fns=[
                            ShowGraph,
                            ActivationStats,
                                  ], 
                    
                    pretrained=True
                    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-3bbc94917b16> in <module>
#       2 # x50 = lambda x: xresnet50()
#       3 learn = cnn_learner(data,models.resnet101,
# ----> 4                     metrics=[error_rate,accuracy,auc_roc_score()],
#       5                     callback_fns=[
#       6                             ShowGraph,
#
# TypeError: auc_roc_score() missing 2 required positional arguments: 'input' and 'targ'

# %%
AUROC??

# %%
learn.model = nn.DataParallel(learn.model)

# %%
learn.load('bestmodel')
# learn.lr_find()
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (1600 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# nv,nv,seborrheic_keratosis,nv,nv
# Path: 2017/ISIC-2017_Training_Data;
#
# Valid: LabelList (400 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# nv,nv,nv,melanoma,nv
# Path: 2017/ISIC-2017_Training_Data;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
class roc(Callback):
    '''
    Updated on March 28 2019 to reflect new change in FastAI's Callback
    ROC_AUC metric callback for fastai. Compute ROC score over each batch and returns the average over batches.
    TO DO: rolling average
    '''
    def on_epoch_begin(self, **kwargs):
        self.total = 0
        self.batch_count = 0
    
    def on_batch_end(self, last_output, last_target, **kwargs):
        preds = F.softmax(last_output, dim=1)
        # roc_auc_score does not work on batches which does not contain both classes.
        try:
            roc_score = roc_auc_score(to_np(last_target), to_np(preds[:,1]))
            self.total += roc_score
            self.batch_count += 1
        except:
            pass
    
    def on_epoch_end(self, last_metrics, **kwargs):
        return add_metrics(last_metrics, self.total/self.batch_count)

# %%
learn.fit_one_cycle(3, callbacks = [
    SaveModelCallback(learn=learn),
    ReduceLROnPlateauCallback(learn=learn)
])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.865600</td>
#       <td>1.262841</td>
#       <td>0.412500</td>
#       <td>0.587500</td>
#       <td>0.378671</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.249634</td>
#       <td>0.796902</td>
#       <td>0.330000</td>
#       <td>0.670000</td>
#       <td>0.307595</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.968222</td>
#       <td>0.775012</td>
#       <td>0.305000</td>
#       <td>0.695000</td>
#       <td>0.322126</td>
#       <td>01:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.2628414630889893.
# ...

# %%
learn

# %%
learn.unfreeze()

# %%
random_seed(7,True)
learn.fit_one_cycle(10, wd=1e-06, max_lr=slice(1e-05,1e-04),callbacks = [
    SaveModelCallback(learn=learn),
    ReduceLROnPlateauCallback(learn=learn),
    AUROC()
])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [2/10 02:44<10:57]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>auroc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(6, figsize=(8,8),heatmap=True)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
def get_balanced_accurracy(a_confusion_matrix):
  balanced_acc = 0
  for i in range(len(matrix[0])):
    row = matrix[i]
    correctGuesses = row[i]
    allPossibleTries = row.sum()
    classAcurracy = correctGuesses / allPossibleTries
    balanced_acc += classAcurracy
#     print(classAcurracy)
  balanced_acc /= len(matrix[0])
  return balanced_acc



matrix = interp.confusion_matrix()
"average acc: ", get_balanced_accurracy(matrix)
# Out:
# ('average acc: ', 0.7044824294871904)

# %%
matrix
# Out:
# array([[ 40,  29,   5],
#        [ 17, 248,   2],
#        [  7,  14,  38]])
